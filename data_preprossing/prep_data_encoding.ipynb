# %%
# parse the body parts
from thesislib.utils import stringutils

# %%
import pathlib
import os
import json
# Out:
# /home/gzr/anaconda3/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# data dir for this advanced nlice parsing
data_dir = "/home/gzr/文档/medvice/thesis/data/basic"
pathlib.Path(data_dir).mkdir(exist_ok=True, parents=True)

# %%
#body_parts_file = "/Users/teliov/TUD/Thesis/Medvice/Notebooks/data/definitions/body-parts.txt"
nlice_file = "/home/gzr/文档/medvice/thesis/data/basic/Nlice-Conditions.json"
by_body_main = {}
with open(nlice_file) as fp:
    nlice_datas = json.load(fp)
for value in nlice_datas.values():
    symptoms = value.get("symptoms")
    for symptom in symptoms:
        nlice = symptoms.get(symptom).get("nlice",{})
        location_main = nlice.get("location_main",None)
        location_keys = nlice.get("location",{}).keys()
        if location_main not in by_body_main and location_main!=None:
            by_body_main[location_main] = []
        for _key in location_keys:
            if(_key not in by_body_main[location_main]):
                by_body_main[location_main].append(_key)
                print(by_body_main[location_main])
# print(by_body_main)
# for body in by_body_main:
#     obj = by_body_main[body]
#     for key in obj:
#         obj[key] = list(obj[key])
parsed_body_parts_file = os.path.join(data_dir, "body-parts.json")
with open(parsed_body_parts_file, "w") as fp:
    json.dump(by_body_main, fp, indent=4)
# Out:
# ['Right_Lower_Quadrant']
# ['Right_Lower_Quadrant', 'Left_abdomen']
# ['Right_Lower_Quadrant', 'Left_abdomen', 'Right_abdomen']
# ['Right_Lower_Quadrant', 'Left_abdomen', 'Right_abdomen', 'Left_Lower_Quadrant']
# ['Right_Lower_Quadrant', 'Left_abdomen', 'Right_abdomen', 'Left_Lower_Quadrant', 'Umbilical_region']
# ['Right_Lower_Quadrant', 'Left_abdomen', 'Right_abdomen', 'Left_Lower_Quadrant', 'Umbilical_region', 'Epigastric_region']
# ['Right_Lower_Quadrant', 'Left_abdomen', 'Right_abdomen', 'Left_Lower_Quadrant', 'Umbilical_region', 'Epigastric_region', 'Lower_abdomen']
# ['Right_Lower_Quadrant', 'Left_abdomen', 'Right_abdomen', 'Left_Lower_Quadrant', 'Umbilical_region', 'Epigastric_region', 'Lower_abdomen', 'Umbilical']
# ['Right_Lower_Quadrant', 'Left_abdomen', 'Right_abdomen', 'Left_Lower_Quadrant', 'Umbilical_region', 'Epigastric_region', 'Lower_abdomen', 'Umbilical', 'Other']
# ['any_MTP1']
# ['any_MTP1', 'big_toe_IP']
# ['any_MTP1', 'big_toe_IP', 'lesser_toes']
# ['any_MTP1', 'big_toe_IP', 'lesser_toes', 'midfoot']
# ['any_MTP1', 'big_toe_IP', 'lesser_toes', 'midfoot', 'ankle']
# ['any_MTP1', 'big_toe_IP', 'lesser_toes', 'midfoot', 'ankle', 'knee_joint']
# ['any_MTP1', 'big_toe_IP', 'lesser_toes', 'midfoot', 'ankle', 'knee_joint', 'hip']
# ['any_MTP1', 'big_toe_IP', 'lesser_toes', 'midfoot', 'ankle', 'knee_joint', 'hip', 'shoulder']
# ['any_MTP1', 'big_toe_IP', 'lesser_toes', 'midfoot', 'ankle', 'knee_joint', 'hip', 'shoulder', 'elbow']
# ['any_MTP1', 'big_toe_IP', 'lesser_toes', 'midfoot', 'ankle', 'knee_joint', 'hip', 'shoulder', 'elbow', 'wrist']
# ['any_MTP1', 'big_toe_IP', 'lesser_toes', 'midfoot', 'ankle', 'knee_joint', 'hip', 'shoulder', 'elbow', 'wrist', 'hand']
# ['any_MTP1', 'big_toe_IP', 'lesser_toes', 'midfoot', 'ankle', 'knee_joint', 'hip', 'shoulder', 'elbow', 'wrist', 'hand', 'CMC']
# ['Unilateral']
# ['Unilateral', 'Bilateral']
# ['Unilateral', 'Bilateral', 'Occiptal_region']
# ['Unilateral', 'Bilateral', 'Occiptal_region', 'Other']
# ['Lower_extremities_or_arms']
# ['Lower_extremities_or_arms', 'Other_bodyparts']
# ['Optic_disc']
# ['Peri-anal,_inner_thighs']
# ['Mucosal_areas']
# ['Optic_disc', 'Conjunctiva']
# ['Neck_and_supraclavicular']
# ['Neck_and_supraclavicular', 'Other']
# /home/gzr/anaconda3/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# let's get an encoding system down
# location would get encoded with 0 if the symptom is not present
# and with 1 if the symptom is present but no location is specified
count = 2 

body_parts_encoded = {}
for key, value in by_body_main.items():
    body_parts_encoded[key] = count
    count += 1
    for part in value:
        body_parts_encoded[part] = count
        count += 1

# %%
encoded_body_parts_file = os.path.join(data_dir, "body-parts-enc.json")
with open(encoded_body_parts_file, "w") as fp:
    json.dump(body_parts_encoded, fp, indent=4)

# %%
# get all the possible nature values
condition_definition_file = "/home/gzr/文档/medvice/thesis/data/basic/Nlice-Conditions.json"

# %%
with open(condition_definition_file) as fp:
    condition_definition = json.load(fp)

# %%
all_nature = set([])
all_excitation = set([])
all_vas = set([])
all_location = set([])
all_frequency = set([])
all_onset = set([])
all_duration = set([])

by_symptom = {}

# %%
for condition_data in condition_definition.values():
    symptoms = condition_data.get("symptoms")
    for symptom in symptoms:
        if symptom not in by_symptom:
            by_symptom[symptom] = {
                "nature": set([]), 
                "location": set([]),
                "location_main": set([]),
                "vas": set([]),
                "excitation": set([]),
                "frequency": set([]),
                "onset":set([]),
                "duration":set([])
            }
        nlice = symptoms.get(symptom).get("nlice", {})
        nature_keys = nlice.get("nature", {}).keys()
        location_keys = nlice.get("location", {}).keys()
        vas_keys = nlice.get("vas", {}).keys()
        excitation_keys = nlice.get("excitation", {}).keys()
        frequency_keys = nlice.get("frequency", {}).keys()
        onset_keys = nlice.get("onset", {}).keys()
        duration_keys = nlice.get("duration", {}).keys()
        location_main = nlice.get("location_main", None)
        
        if location_main:
            by_symptom[symptom]["location_main"].add(location_main)
        
        for _key in nature_keys:
            by_symptom[symptom]["nature"].add(_key)
            all_nature.add(_key)
        
        for _key in location_keys:
            by_symptom[symptom]["location"].add(_key)
            all_location.add(_key)
        
        for _key in vas_keys:
            by_symptom[symptom]["vas"].add(_key)
            all_vas.add(_key)
        
        for _key in excitation_keys:
            by_symptom[symptom]["excitation"].add(_key)
            all_excitation.add(_key)
        
        for _key  in frequency_keys:
            by_symptom[symptom]["frequency"].add(_key)
            all_frequency.add(_key)
            
        for _key  in onset_keys:
            by_symptom[symptom]["onset"].add(_key)
            all_onset.add(_key)
        for _key  in duration_keys:
            by_symptom[symptom]["duration"].add(_key)
            all_duration.add(_key)

# %%
# convert the sets to a list
for symptom in by_symptom:
    obj = by_symptom[symptom]
    for key in obj:
        obj[key] = list(obj[key])

# %%
# save the data
symptom_nlice_file = os.path.join(data_dir, "symptom_nlice.json")
with open(symptom_nlice_file, "w") as fp:
    json.dump(by_symptom, fp, indent=4)

# %%
# save the collection of nlice
all_nlice = {
    "nature": list(all_nature),
    "location": list(all_location),
    "vas": list(all_vas),
    "exciation": list(all_excitation),
    "onset":list(all_onset),
    "duration":list(all_duration)
}

all_nlice_file = os.path.join(data_dir, "all_nlice.json")
with open (all_nlice_file, "w") as fp:
    json.dump(all_nlice, fp, indent=4)
# Out:
# /home/gzr/anaconda3/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# excitation encoding
excitation_encoding = {
    "other": 1
}
count = 2
for item in all_excitation:
    excitation_encoding[item] = count
    count += 1

excitation_encoding_file = os.path.join(data_dir, "excitation_encoding.json")
with open(excitation_encoding_file, "w") as fp:
    json.dump(excitation_encoding, fp, indent=4)

# %%
# vas encoding
vas_encoding = {"other": 1}
count = 2
for item in all_vas:
    vas_encoding[item] = count
    count += 1

vas_encoding_file = os.path.join(data_dir, "vas_encoding.json")
with open(vas_encoding_file, "w") as fp:
    json.dump(vas_encoding, fp, indent=4)

# %%
# nature encoding
nature_encoding = {}
count = 2
for item in all_nature:
    nature_encoding[item] = count
    count += 1
nature_encoding_file = os.path.join(data_dir, "nature_encoding.json")
with open(nature_encoding_file, "w") as fp:
    json.dump(nature_encoding, fp, indent=4)

# %%
# frequency_encoding
frequency_encoding = {
    "other": 1
}
count = 2
for item in all_frequency:
    frequency_encoding[item] = count
    count += 1
frequency_encoding_file = os.path.join(data_dir, "frequency_encoding.json")
with open(frequency_encoding_file, "w") as fp:
    json.dump(frequency_encoding, fp, indent=4)

# %%
# duration_encoding
duration_encoding = {
    "other": 1
}
count = 2
for item in all_duration:
    duration_encoding[item] = count
    count += 1
duration_encoding_file = os.path.join(data_dir, "duration_encoding.json")
with open(duration_encoding_file, "w") as fp:
    json.dump(duration_encoding, fp, indent=4)

# %%
# onset_encoding
onset_encoding = {
    "other": 1
}
count = 2
for item in all_onset:
    onset_encoding[item] = count
    count += 1
onset_encoding_file = os.path.join(data_dir, "onset_encoding.json")
with open(onset_encoding_file, "w") as fp:
    json.dump(onset_encoding, fp, indent=4)

# %%
main_locations = "abdomen, hip, chest, head, left_arm, right_arm, lower_back, lower_extremities"
main_locations = "Chest,Throat,Nose,Head (headache),Abdomen,Skin,Liver,Back,Epigastric,Joints,Extremities,Muscles,Mouth,Limb,Neck,Eye,Lower extremities,Extremities, lower,Calf,Hip,Leg,Hands,"

# %%
# need to augument the json module to force all categories for instance to be present
# for those missing, let's assign a low weight/probability e.g 5%
# let's make magic happen

# %%
updated_definitions = {}
# Out:
# /home/gzr/anaconda3/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
INCLUDE_PERCENT = 5

# %%
def get_all_location(location_main=None, location_list=[]):
    if location_main is not None:
        return [location_main] + by_body_main[location_main]
    
    _locations = []
    for item in location_list:
        found = []
        for key, locations in by_body_main.items():
            if item == key or item in locations:
                found = get_all_location(key)
                break
        if len(found) == 0:
            found = [item]
        _locations += found
    
    return _locations
# Out:
# /home/gzr/anaconda3/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
for condition, condition_data in condition_definition.items():
    updated_definitions[condition] = condition_data
    
    symptoms = condition_data.get("symptoms")
    updated_symptoms = {}
    for symptom in symptoms:
        symptom_data = symptoms[symptom]
        nlice_data = symptom_data.get("nlice", {})
        
        # nature
        nature = nlice_data.get("nature", {})
        full_nature = by_symptom[symptom].get("nature", [])
        
        for item in full_nature:
            if item not in nature:
                nature[item] = INCLUDE_PERCENT
        
        # location
        location_main = nlice_data.get("location_main", None)
        location = nlice_data.get("location", {})
        _all_locations = get_all_location(location_main, location)
        
        for item in _all_locations:
            if item not in location:
                location[item] = INCLUDE_PERCENT
        
        # intensity/vas
        vas = nlice_data.get("vas", {})
        if len(vas) == 0:
            vas["other"] = 90
        for item in vas_encoding.keys():
            if item not in vas:
                vas[item] = INCLUDE_PERCENT
        
        # excitation
        excitation = nlice_data.get("excitation", {})
        if len(excitation) == 0:
            excitation["other"] = 90
        
        for item in excitation_encoding:
            if item not in excitation:
                excitation[item] = INCLUDE_PERCENT
        
        # frequency
        frequency = nlice_data.get("frequency", {})
        if len(frequency) == 0:
            frequency["other"] = 90
        
        for item in frequency_encoding:
            if item not in frequency:
                frequency[item] = INCLUDE_PERCENT
        #onset
        onset = nlice_data.get("onset", {})
        if len(onset) == 0:
            onset["other"] = 90
        
        for item in onset_encoding:
            if item not in onset:
                onset[item] = INCLUDE_PERCENT
        #duration
        duration = nlice_data.get("duration", {})
        if len(duration) == 0:
            duration["other"] = 90
        
        for item in duration_encoding:
            if item not in duration:
                duration[item] = INCLUDE_PERCENT
        if len(nature) > 0:
            nlice_data["nature"] = nature
        if len(location) > 0:
            nlice_data["location"] = location
        if len(vas) > 0:
            nlice_data["vas"] = vas
        if len(excitation) > 0:
            nlice_data["excitation"] = excitation
        if len(frequency) > 0:
            nlice_data["frequency"] = frequency

        if len(onset) > 0:
            nlice_data["onset"] = onset
        if len(duration)>0:
            nlice_data["duration"] = duration
        
        symptom_data["nlice"] = nlice_data
        updated_symptoms[symptom] = symptom_data
    updated_definitions[condition]["symptoms"] = updated_symptoms

# %%
# save the updated definition file
updated_definitions_file = os.path.join(data_dir, "ai-nlice-adv-updated.json")
with open(updated_definitions_file, "w") as fp:
    json.dump(updated_definitions, fp, indent=4)

# %%
conditions = sorted(updated_definitions.keys())

# %%
condition_db = {code: idx for idx, code in enumerate(conditions)}

# %%
condition_db_file = os.path.join(data_dir, "conditions_db.json")
with open(condition_db_file, "w") as fp:
    json.dump(condition_db, fp, indent=4)

# %%
symptoms = sorted(by_symptom.keys())

# %%
symptom_db = {code: idx for idx, code in enumerate(symptoms)}

# %%
symptom_db_file = os.path.join(data_dir, "symptoms_db.json")
with open(symptom_db_file, "w") as fp:
    json.dump(symptom_db, fp, indent=4)

# %%
by_symptom = {}
for condition_data in updated_definitions.values():
    symptoms = condition_data.get("symptoms")
    for symptom in symptoms:
        if symptom not in by_symptom:
            by_symptom[symptom] = {
                "nature": set([]), 
                "location": set([]),
                "location_main": set([]),
                "vas": set([]),
                "excitation": set([]),
                "frequency": set([])
            }
        nlice = symptoms.get(symptom).get("nlice", {})
        nature_keys = nlice.get("nature", {}).keys()
        location_keys = nlice.get("location", {}).keys()
        vas_keys = nlice.get("vas", {}).keys()
        excitation_keys = nlice.get("excitation", {}).keys()
        frequency_keys = nlice.get("frequency", {}).keys()
        
        location_main = nlice.get("location_main", None)
        
        if location_main:
            by_symptom[symptom]["location_main"].add(location_main)
        
        for _key in nature_keys:
            by_symptom[symptom]["nature"].add(_key)
        
        for _key in location_keys:
            by_symptom[symptom]["location"].add(_key)
        
        for _key in vas_keys:
            if _key == "other":
                continue
            by_symptom[symptom]["vas"].add(_key)
        
        for _key in excitation_keys:
            if _key == "other":
                continue
            by_symptom[symptom]["excitation"].add(_key)
        
        for _key  in frequency_keys:
            if _key == "other":
                continue
            by_symptom[symptom]["frequency"].add(_key)

# %%
# convert the sets to a list
for symptom in by_symptom:
    obj = by_symptom[symptom]
    for key in obj:
        obj[key] = list(obj[key])

# %%
updated_nlice_symptom_file = os.path.join(data_dir, "symptom_nlice_updated.json")
with open(updated_nlice_symptom_file, "w") as fp:
    json.dump(by_symptom, fp, indent=4)

# %%
by_symptom
# Out:
# {'nausea': {'nature': [],
#   'location': [],
#   'location_main': [],
#   'vas': ['moderate', 'severe', 'mild'],
#   'excitation': ['worsening_after_meals',
#    'walking',
#    'car_over_bumps',
#    'walking_bending_forward',
#    'sitting_bending_forward',
#    'standing'],
#   'frequency': ['regular', 'rare', 'often']},
#  'abdominal_pain': {'nature': ['stinging', 'dull', 'cramping'],
#   'location': ['abdomen_upper_abdomen',
#    'abdomen_urq',
#    'abdomen_llq',
#    'abdomen_umbilical',
#    'abdomen_right_abdomen',
#    'abdomen_lower_abdomen',
#    'abdomen_epigastric',
#    'abdomen_lrq',
#    'abdomen_ulq',
#    'abdomen_left_abdomen',
#    'abdomen'],
#   'location_main': ['abdomen'],
#   'vas': ['moderate', 'severe', 'mild'],
#   'excitation': ['worsening_after_meals',
#    'walking',
#    'car_over_bumps',
#    'walking_bending_forward',
#    'sitting_bending_forward',
#    'standing'],
#   'frequency': ['regular', 'rare', 'often']},
#  'vomiting': {'nature': [],
#   'location': [],
#   'location_main': [],
#   'vas': ['moderate', 'severe', 'mild'],
#   'excitation': ['worsening_after_meals',
#    'walking',
#    'car_over_bumps',
#    'walking_bending_forward',
#    'sitting_bending_forward',
#    'standing'],
#   'frequency': ['regular', 'rare', 'often']},
#  'anorexia': {'nature': [],
#   'location': [],
#   'location_main': [],
#   'vas': ['moderate', 'severe', 'mild'],
#   'excitation': ['worsening_after_meals',
#    'walking',
#    'car_over_bumps',
#    'walking_bending_forward',
#    'sitting_bending_forward',
#    'standing'],
#   'frequency': ['regular', 'rare', 'often']},
#  'fever': {'nature': [],
#   'location': [],
#   'location_main': [],
#   'vas': ['moderate', 'severe', 'mild'],
#   'excitation': ['worsening_after_meals',
#    'walking',
#    'car_over_bumps',
#    'walking_bending_forward',
#    'sitting_bending_forward',
#    'standing'],
#   'frequency': ['regular', 'rare', 'often']},
#  'bloating': {'nature': [],
#   'location': [],
#   'location_main': [],
#   'vas': ['moderate', 'severe', 'mild'],
#   'excitation': ['worsening_after_meals',
#    'walking',
#    'car_over_bumps',
#    'walking_bending_forward',
#    'sitting_bending_forward',
#    'standing'],
#   'frequency': ['regular', 'rare', 'often']},
#  'hard_stool': {'nature': ['lumpy'],
#   'location': [],
#   'location_main': [],
#   'vas': ['moderate', 'severe', 'mild'],
#   'excitation': ['worsening_after_meals',
#    'walking',
#    'car_over_bumps',
#    'walking_bending_forward',
#    'sitting_bending_forward',
#    'standing'],
#   'frequency': ['regular', 'rare', 'often']},
#  'jaundice': {'nature': [],
#   'location': [],
#   'location_main': [],
#   'vas': ['moderate', 'severe', 'mild'],
#   'excitation': ['worsening_after_meals',
#    'walking',
#    'car_over_bumps',
#    'walking_bending_forward',
#    'sitting_bending_forward',
#    'standing'],
#   'frequency': ['regular', 'rare', 'often']},
#  'flatulence': {'nature': [],
#   'location': [],
#   'location_main': [],
#   'vas': ['moderate', 'severe', 'mild'],
#   'excitation': ['worsening_after_meals',
#    'walking',
#    'car_over_bumps',
#    'walking_bending_forward',
#    'sitting_bending_forward',
#    'standing'],
#   'frequency': ['regular', 'rare', 'often']},
#  'lower_back_pain': {'nature': ['radiating'],
#   'location': ['lower_back_paravertebral',
#    'lower_back_si',
#    'lower_back_lumbar',
#    'lower_back_left_flank',
#    'lower_back_right_flank',
#    'lower_back'],
#   'location_main': ['lower_back'],
#   'vas': ['moderate', 'severe', 'mild'],
#   'excitation': ['worsening_after_meals',
#    'walking',
#    'car_over_bumps',
#    'walking_bending_forward',
#    'sitting_bending_forward',
#    'standing'],
#   'frequency': ['regular', 'rare', 'often']},
#  'cough': {'nature': [],
#   'location': [],
#   'location_main': [],
#   'vas': ['moderate', 'severe', 'mild'],
#   'excitation': ['worsening_after_meals',
#    'walking',
#    'car_over_bumps',
#    'walking_bending_forward',
#    'sitting_bending_forward',
#    'standing'],
#   'frequency': ['regular', 'rare', 'often']},
#  'mucus_expectoration': {'nature': [],
#   'location': [],
#   'location_main': [],
#   'vas': ['moderate', 'severe', 'mild'],
#   'excitation': ['worsening_after_meals',
#    'walking',
#    'car_over_bumps',
#    'walking_bending_forward',
#    'sitting_bending_forward',
#    'standing'],
#   'frequency': ['regular', 'rare', 'often']},
#  'shortness_of_breath': {'nature': [],
#   'location': [],
#   'location_main': [],
#   'vas': ['moderate', 'severe', 'mild'],
#   'excitation': ['worsening_after_meals',
#    'walking',
#    'car_over_bumps',
#    'walking_bending_forward',
#    'sitting_bending_forward',
#    'standing'],
#   'frequency': ['regular', 'rare', 'often']},
#  'fatigue': {'nature': [],
#   'location': [],
#   'location_main': [],
#   'vas': ['moderate', 'severe', 'mild'],
#   'excitation': ['worsening_after_meals',
#    'walking',
#    'car_over_bumps',
#    'walking_bending_forward',
#    'sitting_bending_forward',
#    'standing'],
#   'frequency': ['regular', 'rare', 'often']},
#  'head_pain': {'nature': ['pressure',
#    'aching',
#    'stabbing',
#    'throbbing',
#    'thunderclap'],
#   'location': ['head_left_ear',
#    'head_occipital',
#    'head_temporal_left',
#    'head_trapezius',
#    'head',
#    'head_neck',
#    'head_throat',
#    'head_chin',
#    'head_temporal_right',
#    'head_unilateral_right',
#    'head_left_eye',
#    'head_mastoid',
#    'head_nose',
#    'head_right_eye',
#    'head_unilateral_left',
#    'head_jaw',
#    'head_forehead',
#    'head_top',
#    'head_nostrils',
#    'head_right_ear',
#    'head_bilateral_side',
#    'head_mouth',
#    'head_cheek',
#    'head_cervical'],
#   'location_main': ['head'],
#   'vas': ['moderate', 'severe', 'mild'],
#   'excitation': ['worsening_after_meals',
#    'walking',
#    'car_over_bumps',
#    'walking_bending_forward',
#    'sitting_bending_forward',
#    'standing'],
#   'frequency': ['regular', 'rare', 'often']},
#  'sore_throat': {'nature': [],
#   'location': [],
#   'location_main': [],
#   'vas': ['moderate', 'severe', 'mild'],
#   'excitation': ['worsening_after_meals',
#    'walking',
#    'car_over_bumps',
#    'walking_bending_forward',
#    'sitting_bending_forward',
#    'standing'],
#   'frequency': ['regular', 'rare', 'often']},
#  'nasal_congestion': {'nature': [],
#   'location': [],
#   'location_main': [],
#   'vas': ['moderate', 'severe', 'mild'],
#   'excitation': ['worsening_after_meals',
#    'walking',
#    'car_over_bumps',
#    'walking_bending_forward',
#    'sitting_bending_forward',
#    'standing'],
#   'frequency': ['regular', 'rare', 'often']},
#  'cyanosis': {'nature': [],
#   'location': [],
#   'location_main': [],
#   'vas': ['moderate', 'severe', 'mild'],
#   'excitation': ['worsening_after_meals',
#    'walking',
#    'car_over_bumps',
#    'walking_bending_forward',
#    'sitting_bending_forward',
#    'standing'],
#   'frequency': ['regular', 'rare', 'often']},
#  'chest_pain': {'nature': ['stinging', 'cramping'],
#   'location': ['chest_upper_left_chest',
#    'chest_right_clavicle',
#    'chest_ribs_left',
#    'chest_shoulderblade_right',
#    'chest_upper_flank_right',
#    'chest_upper_flank_left',
#    'chest_upper_spine',
#    'chest_sternum',
#    'chest_lower_left_chest',
#    'chest_lower_right_chest',
#    'chest_middle_spine',
#    'chest_upper_right_chest',
#    'chest_ribs_right',
#    'chest_left_clavicle',
#    'chest_shoulderblade_left',
#    'chest',
#    'chest_middle_upper_back'],
#   'location_main': ['chest'],
#   'vas': ['moderate', 'severe', 'mild'],
#   'excitation': ['worsening_after_meals',
#    'walking',
#    'car_over_bumps',
#    'walking_bending_forward',
#    'sitting_bending_forward',
#    'standing'],
#   'frequency': ['regular', 'rare', 'often']},
#  'headache': {'nature': [],
#   'location': [],
#   'location_main': [],
#   'vas': ['moderate', 'severe', 'mild'],
#   'excitation': ['worsening_after_meals',
#    'walking',
#    'car_over_bumps',
#    'walking_bending_forward',
#    'sitting_bending_forward',
#    'standing'],
#   'frequency': ['regular', 'rare', 'often']},
#  'photophobia': {'nature': [],
#   'location': [],
#   'location_main': [],
#   'vas': ['moderate', 'severe', 'mild'],
#   'excitation': ['worsening_after_meals',
#    'walking',
#    'car_over_bumps',
#    'walking_bending_forward',
#    'sitting_bending_forward',
#    'standing'],
#   'frequency': ['regular', 'rare', 'often']},
#  'phonophobia': {'nature': [],
#   'location': [],
#   'location_main': [],
#   'vas': ['moderate', 'severe', 'mild'],
#   'excitation': ['worsening_after_meals',
#    'walking',
#    'car_over_bumps',
#    'walking_bending_forward',
#    'sitting_bending_forward',
#    'standing'],
#   'frequency': ['regular', 'rare', 'often']},
#  'aura': {'nature': [],
#   'location': [],
#   'location_main': [],
#   'vas': ['moderate', 'severe', 'mild'],
#   'excitation': ['worsening_after_meals',
#    'walking',
#    'car_over_bumps',
#    'walking_bending_forward',
#    'sitting_bending_forward',
#    'standing'],
#   'frequency': ['regular', 'rare', 'often']},
#  'limb_weakness': {'nature': ['contraleteral_proximal_weakness',
#    'hemiparesis',
#    'paraparesis'],
#   'location': ['right_arm_backhand',
#    'right_arm_upper_arm',
#    'right_arm_dig3',
#    'left_arm_backhand',
#    'lower_extremities_unilateral_right_leg',
#    'left_arm_upper_arm',
#    'right_arm_dig4',
#    'right_arm',
#    'lower_extremities_sole',
#    'lower_extremities_forefoot',
#    'lower_extremities_lower_leg_right',
#    'lower_extremities_foot',
#    'lower_extremities_adductor',
#    'lower_extremities',
#    'left_arm_palm',
#    'lower_extremities_hamstrings',
#    'left_arm_hand',
#    'left_arm_thumb',
#    'left_arm_dig3',
#    'lower_extremities_quadriceps',
#    'left_arm_wrist',
#    'right_arm_hand',
#    'left_arm_epicondyle',
#    'left_arm_dig2',
#    'lower_extremities_ankle',
#    'lower_extremities_popliteal',
#    'right_arm_epicondyle',
#    'right_arm_dig2',
#    'lower_extremities_heel',
#    'right_arm_dig5',
#    'lower_extremities_dig5',
#    'lower_extremities_unilateral_left_leg',
#    'left_arm',
#    'lower_extremities_calve',
#    'lower_extremities_dig1',
#    'lower_extremities_knee',
#    'left_arm_dig4',
#    'left_arm_lower_arm',
#    'right_arm_thumb',
#    'lower_extremities_upper_leg_right',
#    'right_arm_wrist',
#    'lower_extremities_abductor',
#    'left_arm_dig5',
#    'lower_extremities_dig2',
#    'lower_extremities_bilateral_legs',
#    'lower_extremities_dig3',
#    'lower_extremities_upper_leg_left',
#    'right_arm_lower_arm',
#    'lower_extremities_lower_leg_left',
#    'right_arm_palm',
#    'lower_extremities_dig4'],
#   'location_main': [],
#   'vas': ['moderate', 'severe', 'mild'],
#   'excitation': ['worsening_after_meals',
#    'walking',
#    'car_over_bumps',
#    'walking_bending_forward',
#    'sitting_bending_forward',
#    'standing'],
#   'frequency': ['regular', 'rare', 'often']},
#  'double_vision': {'nature': [],
#   'location': [],
#   'location_main': [],
#   'vas': ['moderate', 'severe', 'mild'],
#   'excitation': ['worsening_after_meals',
#    'walking',
#    'car_over_bumps',
#    'walking_bending_forward',
#    'sitting_bending_forward',
#    'standing'],
#   'frequency': ['regular', 'rare', 'often']},
#  'head_stiffness': {'nature': [],
#   'location': ['head_left_ear',
#    'head_occipital',
#    'head_temporal_left',
#    'head_trapezius',
#    'head',
#    'head_neck',
#    'head_throat',
#    'head_chin',
#    'head_temporal_right',
#    'head_unilateral_right',
#    'head_left_eye',
#    'head_mastoid',
#    'head_nose',
#    'head_right_eye',
#    'head_unilateral_left',
#    'head_jaw',
#    'head_forehead',
#    'head_top',
#    'head_nostrils',
#    'head_right_ear',
#    'head_bilateral_side',
#    'head_mouth',
#    'head_cheek',
#    'head_cervical'],
#   'location_main': ['head'],
#   'vas': ['moderate', 'severe', 'mild'],
#   'excitation': ['worsening_after_meals',
#    'walking',
#    'car_over_bumps',
#    'walking_bending_forward',
#    'sitting_bending_forward',
#    'standing'],
#   'frequency': ['regular', 'rare', 'often']},
#  'loss_of_consciousness': {'nature': [],
#   'location': [],
#   'location_main': [],
#   'vas': ['moderate', 'severe', 'mild'],
#   'excitation': ['worsening_after_meals',
#    'walking',
#    'car_over_bumps',
#    'walking_bending_forward',
#    'sitting_bending_forward',
#    'standing'],
#   'frequency': ['regular', 'rare', 'often']},
#  'transient_focal_symptoms': {'nature': [],
#   'location': [],
#   'location_main': [],
#   'vas': ['moderate', 'severe', 'mild'],
#   'excitation': ['worsening_after_meals',
#    'walking',
#    'car_over_bumps',
#    'walking_bending_forward',
#    'sitting_bending_forward',
#    'standing'],
#   'frequency': ['regular', 'rare', 'often']},
#  'lower_extremities_pain': {'nature': ['radiating'],
#   'location': ['lower_extremities_unilateral_right_leg',
#    'lower_extremities_sole',
#    'lower_extremities_forefoot',
#    'lower_extremities_lower_leg_right',
#    'lower_extremities_foot',
#    'lower_extremities_adductor',
#    'lower_extremities',
#    'lower_extremities_hamstrings',
#    'lower_extremities_quadriceps',
#    'lower_extremities_ankle',
#    'lower_extremities_popliteal',
#    'lower_extremities_heel',
#    'lower_extremities_dig5',
#    'lower_extremities_unilateral_left_leg',
#    'lower_extremities_calve',
#    'lower_extremities_dig1',
#    'lower_extremities_knee',
#    'lower_extremities_upper_leg_right',
#    'lower_extremities_abductor',
#    'lower_extremities_dig2',
#    'lower_extremities_bilateral_legs',
#    'lower_extremities_dig3',
#    'lower_extremities_upper_leg_left',
#    'lower_extremities_lower_leg_left',
#    'lower_extremities_dig4'],
#   'location_main': ['lower_extremities'],
#   'vas': ['moderate', 'severe', 'mild'],
#   'excitation': ['worsening_after_meals',
#    'walking',
#    'car_over_bumps',
#    'walking_bending_forward',
#    'sitting_bending_forward',
#    'standing'],
#   'frequency': ['regular', 'rare', 'often']},
#  'sensibility_problems': {'nature': ['numbness', 'tingling', 'radiating'],
#   'location': ['hip_glute_left',
#    'hip_glute_right',
#    'lower_extremities_unilateral_right_leg',
#    'lower_extremities_sole',
#    'lower_extremities_forefoot',
#    'lower_extremities_lower_leg_right',
#    'lower_extremities_foot',
#    'lower_extremities_adductor',
#    'lower_extremities',
#    'lower_extremities_hamstrings',
#    'hip_right_inguinal_groin',
#    'lower_extremities_quadriceps',
#    'hip_left_inguinal_groin',
#    'lower_extremities_ankle',
#    'lower_extremities_popliteal',
#    'hip_pubic_area',
#    'lower_extremities_heel',
#    'lower_extremities_dig5',
#    'lower_extremities_unilateral_left_leg',
#    'lower_extremities_calve',
#    'lower_extremities_dig1',
#    'lower_extremities_knee',
#    'hip',
#    'lower_extremities_upper_leg_right',
#    'hip_left_hipbone',
#    'hip_coccyx',
#    'lower_extremities_abductor',
#    'lower_extremities_dig2',
#    'lower_extremities_bilateral_legs',
#    'hip_peri-anal',
#    'lower_extremities_dig3',
#    'lower_extremities_upper_leg_left',
#    'hip_inner_thighs',
#    'lower_extremities_lower_leg_left',
#    'hip_right_hipbone',
#    'lower_extremities_dig4'],
#   'location_main': ['hip', 'lower_extremities'],
#   'vas': ['moderate', 'severe', 'mild'],
#   'excitation': ['worsening_after_meals',
#    'walking',
#    'car_over_bumps',
#    'walking_bending_forward',
#    'sitting_bending_forward',
#    'standing'],
#   'frequency': ['regular', 'rare', 'often']},
#  'pain_relief': {'nature': [],
#   'location': [],
#   'location_main': [],
#   'vas': ['moderate', 'severe', 'mild'],
#   'excitation': ['worsening_after_meals',
#    'walking',
#    'car_over_bumps',
#    'walking_bending_forward',
#    'sitting_bending_forward',
#    'standing'],
#   'frequency': ['regular', 'rare', 'often']},
#  'intermittent_claudication': {'nature': [],
#   'location': [],
#   'location_main': [],
#   'vas': ['moderate', 'severe', 'mild'],
#   'excitation': ['worsening_after_meals',
#    'walking',
#    'car_over_bumps',
#    'walking_bending_forward',
#    'sitting_bending_forward',
#    'standing'],
#   'frequency': ['regular', 'rare', 'often']},
#  'incontinence': {'nature': [],
#   'location': [],
#   'location_main': [],
#   'vas': ['moderate', 'severe', 'mild'],
#   'excitation': ['worsening_after_meals',
#    'walking',
#    'car_over_bumps',
#    'walking_bending_forward',
#    'sitting_bending_forward',
#    'standing'],
#   'frequency': ['regular', 'rare', 'often']}}
